# %%
import mayavi

# %%
# %gui qt

# %%
from mayavi import mlab
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pyface/qt/QtWebKit.py in <module>
#      18     try:
# ---> 19         from PyQt5.QtWebEngine import *
#      20         from PyQt5.QtWebEngineWidgets import (
#
# ModuleNotFoundError: No module named 'PyQt5.QtWebEngine'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-67847bc6bfd0> in <module>
# ----> 1 from mayavi import mlab
#
# ~/.local/lib/python3.6/site-packages/mayavi/mlab.py in <module>
#      14 # Mayavi imports
#      15 from mayavi.core.common import process_ui_events
# ---> 16 from mayavi.tools.camera import view, roll, yaw, pitch, move
#      17 from mayavi.tools.figure import figure, clf, gcf, savefig, \
#      18     draw, sync_camera, close, screenshot
#
# ...
